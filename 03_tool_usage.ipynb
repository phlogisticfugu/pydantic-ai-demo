# %%
import os
from dotenv import load_dotenv
import logfire
from rich import print as rich_print

load_dotenv()


LOGFIRE_WRITE_TOKEN = os.getenv('LOGFIRE_WRITE_TOKEN')
logfire.configure(token=LOGFIRE_WRITE_TOKEN)
logfire.instrument_pydantic_ai()
logfire.instrument_httpx()
# Out:
# Logfire project URL: ]8;id=322067;https://logfire-us.pydantic.dev/brad-ito/pydantic-ai-demo\https://logfire-us.pydantic.dev/brad-ito/pydantic-ai-demo]8;;\

# %%
import ollama
from pydantic_ai.models.openai import OpenAIChatModel
from pydantic_ai.providers.ollama import OllamaProvider

OLLAMA_MODEL_NAME = "gpt-oss:20b"
OLLAMA_BASE_URL = "http://localhost:11434"

ollama.pull(OLLAMA_MODEL_NAME)

ollama_model = OpenAIChatModel(
    model_name=OLLAMA_MODEL_NAME,
    provider=OllamaProvider(base_url=f"{OLLAMA_BASE_URL}/v1", api_key="ollama"),
)
# Out:
# 13:37:12.843 POST 127.0.0.1/api/pull

# %%
import os

from pydantic_ai import Agent
from pydantic_ai.common_tools.tavily import tavily_search_tool

TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')

search_agent = Agent(
    ollama_model,
    tools=[tavily_search_tool(TAVILY_API_KEY)],
    system_prompt='Search Tavily for the given query and return a short summary of the results in markdown format.  Include the title, url, and snippet of the results.',
)

# %%
search_result = await search_agent.run('Why is the sky blue?')
print(search_result.output)
rich_print(search_result.usage())
# Out:
# 13:37:25.668 search_agent run
# 13:37:25.673   chat gpt-oss:20b
# 13:37:25.676     POST localhost/v1/chat/completions
# 13:37:41.455   running 1 tool
# 13:37:41.457     running tool: tavily_search
# 13:37:41.470   chat gpt-oss:20b
# 13:37:41.473     POST localhost/v1/chat/completions
# 13:37:44.597   running 1 tool
# 13:37:44.597     running tool: tavily_search
# 13:37:44.606       POST api.tavily.com/search
# 13:37:47.581   chat gpt-oss:20b
# 13:37:47.583     POST localhost/v1/chat/completions
# ## Short Summary of Search Results
#
# | Title | URL | Snippet |
# |-------|-----|---------|
# | Why is the sky blue? | <https://www.rmg.co.uk/stories/space-astronomy/why-sky-blue> | “Clear skies above the Royal Observatory make for a fantastic view – but why is the sky blue? It’s the Earth’s atmosphere, and a process known as ‘scattering’, that causes our skies to be blue… As white light passes through our atmosphere, tiny air molecules cause it to ‘scatter’. The scattering caused by these tiny air molecules (known as Rayleigh scattering) increases as the wavelength of light decreases.” |
# | Why Is the Sky Blue? | <https://spaceplace.nasa.gov/blue-sky/en/> | “Sunlight reaches Earth's atmosphere and is scattered in all directions by all the gases and particles in the air. Blue light is scattered more than the other colors because it travels as shorter, smaller waves. This is why we see a blue sky most of the time.” |
# | Why Is the Sky Blue? – YouTube | <https://www.youtube.com/watch?v=ehUIlhKhzDA> | “…the sky is usually a shade of blue. Why blue—and not purple, green, or orange? It’s all because of how the Sun’s light reaches Earth! … The white light from the Sun is made of all the colors of the rainbow, and the blue component is scattered in all directions by the tiny molecules of air.” |
# | Why is the sky blue? – Live Science | <https://www.livescience.com/planet-earth/why-is-the-sky-blue> | “We see blue above us because of how light from the sun interacts with Earth's atmosphere. When the white light traveling from the sun reaches Earth, some of the colors interact with molecules and small particles in the atmosphere, and blue light is scattered more than other colors.” |
# | Why Is the Sky Blue? | <https://www.nesdis.noaa.gov/about/k-12-education/atmosphere/why-the-sky-blue> | “Gases and particles in Earth's atmosphere scatter sunlight in all directions. Blue light is scattered more than other colors because it travels as shorter, smaller waves.” |
#
# These sources collectively explain that the sky appears blue due to **Rayleigh scattering**: short‑wavelength blue light is scattered more efficiently by the small molecules in Earth's atmosphere than longer‑wavelength colors, making the sky’s dominant color blue.
# RunUsage(input_tokens=2597, output_tokens=684, requests=3, tool_calls=1)

# %%
rich_print(search_result.all_messages())
# Out:
# [
#     ModelRequest(parts=[SystemPromptPart(content='Search Tavily for the given query and return a short summary of
# the results in markdown format.  Include the title, url, and snippet of the results.',
# timestamp=datetime.datetime(2025, 11, 4, 19, 37, 25, 672006, tzinfo=datetime.timezone.utc)),
# UserPromptPart(content='Why is the sky blue?', timestamp=datetime.datetime(2025, 11, 4, 19, 37, 25, 672037,
# tzinfo=datetime.timezone.utc))]),
#     ModelResponse(parts=[ThinkingPart(content='We need to search on Tavily for "Why is the sky blue?" Then produce
# a short summary of the results in markdown format, including title, url, snippet. Use function.', id='reasoning',
# provider_name='ollama'), ToolCallPart(tool_name='tavily_search', args='{"query":"Why is the sky
# blue?","search_deep":"true","time_range":null,"topic":"science"}', tool_call_id='call_it88zyoq')],
# usage=RequestUsage(input_tokens=230, output_tokens=83), model_name='gpt-oss:20b', timestamp=datetime.datetime(2025,
# 11, 4, 19, 37, 41, tzinfo=TzInfo(0)), provider_name='ollama', provider_details={'finish_reason': 'tool_calls'},
# provider_response_id='chatcmpl-332', finish_reason='tool_call'),
#     ModelRequest(parts=[RetryPromptPart(content=[{'type': 'literal_error', 'loc': ('search_deep',), 'msg': "Input
# should be 'basic' or 'advanced'", 'input': 'true'}, {'type': 'literal_error', 'loc': ('topic',), 'msg': "Input
# should be 'general' or 'news'", 'input': 'science'}], tool_name='tavily_search', tool_call_id='call_it88zyoq',
# timestamp=datetime.datetime(2025, 11, 4, 19, 37, 41, 459727, tzinfo=datetime.timezone.utc))]),
#     ModelResponse(parts=[ThinkingPart(content='The params should be search_deep: "basic" or "advanced". We\'ll use
# "advanced". topic: "general" or "news". We\'ll use "general". Let\'s re-run.', id='reasoning',
# provider_name='ollama'), ToolCallPart(tool_name='tavily_search', args='{"query":"Why is the sky
# blue?","search_deep":"advanced","time_range":null,"topic":"general"}', tool_call_id='call_9myz2dr7')],
# usage=RequestUsage(input_tokens=437, output_tokens=84), model_name='gpt-oss:20b', timestamp=datetime.datetime(2025,
# 11, 4, 19, 37, 44, tzinfo=TzInfo(0)), provider_name='ollama', provider_details={'finish_reason': 'tool_calls'},
# provider_response_id='chatcmpl-834', finish_reason='tool_call'),
#     ModelRequest(parts=[ToolReturnPart(tool_name='tavily_search', content=[{'title': 'Why is the sky blue? | Royal
# Observatory', 'url': 'https://www.rmg.co.uk/stories/space-astronomy/why-sky-blue', 'content': "Our sites\n\nWhy is
# the sky blue?\n\nClear skies above the Royal Observatory make for a fantastic view – but why is the sky
# blue?\n\nIt’s a common misconception that the sky is blue because it reflects the blue of the seas and
# oceans.\n\nIn fact, it’s the Earth’s atmosphere, and a process known as 'scattering', that causes our skies to be
# blue.\n\nLearn more with astronomers at the Royal Observatory Greenwich.\n\nThis content is hosted by a third
# party\n\nPlease allow all cookies to watch the video. [...] Why is the sky blue?\n\nHere's the short
# answer...\n\nAs white light passes through our atmosphere, tiny air molecules cause it to ‘scatter’.\n\nThe
# scattering caused by these tiny air molecules (known as Rayleigh scattering) increases as the wavelength of light
# decreases.\n\nViolet and blue light have the shortest wavelengths and red light has the longest.\n\nTherefore, blue
# light is scattered more than red light and the sky appears blue during the day. [...] At noon, when the Sun is
# overhead it appears white. This is because the light travels a shorter distance through the atmosphere to get to
# us; it’s scattered very little, even the blue light.\n\nDuring the day the sky looks blue because it’s the blue
# light that gets scattered the most. It’s redirected into many different directions all over the sky, whereas the
# other wavelengths aren’t scattered as much.", 'score': 0.918663}, {'title': 'Why Is the Sky Blue? | NASA Space
# Place – NASA Science for Kids', 'url': 'https://spaceplace.nasa.gov/blue-sky/en/', 'content': "Due to the lapse in
# federal government funding, NASA is not updating this website.\n\nVea en Español\n\nmisr\n\n# Why Is the Sky
# Blue?\n\nThe Short Answer:\n\nSunlight reaches Earth's atmosphere and is scattered in all directions by all the
# gases and particles in the air. Blue light is scattered more than the other colors because it travels as shorter,
# smaller waves. This is why we see a blue sky most of the time. [...] Sunlight reaches Earth's atmosphere and is
# scattered in all directions by all the gases and particles in the air. Blue light is scattered in all directions by
# the tiny molecules of air in Earth's atmosphere. Blue is scattered more than other colors because it travels as
# shorter, smaller waves. This is why we see a blue sky most of the time. [...] Closer to the horizon, the sky fades
# to a lighter blue or white. The sunlight reaching us from low in the sky has passed through even more air than the
# sunlight reaching us from overhead. As the sunlight has passed through all this air, the air molecules have
# scattered and rescattered the blue light many times in many directions.\n\nAlso, the surface of Earth has reflected
# and scattered the light. All this scattering mixes the colors together again so we see more white and less blue.",
# 'score': 0.91288006}, {'title': 'Why Is the Sky Blue? - YouTube', 'url':
# 'https://www.youtube.com/watch?v=ehUIlhKhzDA', 'content': "### Transcript:\nWhy Is the Sky Blue? In the middle of a
# bright, sunny day, the\nsky is usually a shade of blue. Why blue—and not purple, green, or orange? Well, it’s all
# because of how the Sun’s\nlight reaches Earth! If you see light from the Sun hitting the\nground, it probably looks
# like plain white light. However, that white light is made up of all\nthe colors of the rainbow. You can actually
# separate and see all these [...] # Why Is the Sky Blue?\n## NASA Space Place\n61200 subscribers\n5668 likes\n\n###
# Description\n837919 views\nPosted: 2 Mar 2020\nWhy is the sky blue and not purple, green or orange? It's all
# because of how the Sun's light reaches Earth!", 'score': 0.910998}, {'title': 'Why is the sky blue? - Live
# Science', 'url': 'https://www.livescience.com/planet-earth/why-is-the-sky-blue', 'content': "We see blue above us
# because of how light from the sun interacts with Earth's atmosphere. The visible light spectrum contains a variety
# of colors, ranging from red light to violet. When all of the colors are mixed, the light appears white, Marc
# Chenard, a meteorologist at the National Weather Service, told Live Science. But once the white light traveling
# from the sun reaches Earth, some of the colors begin to interact with molecules and small particles in the
# atmosphere, he said. [...] When you purchase through links on our site, we may earn an affiliate commission. Here’s
# how it works.\n\nBlue sky and white cloud nature background.\n\nMolecules in our atmosphere scatter light from the
# sun, which makes our sky appear blue.\n(Image credit: Pongnathee Kluaythong via Getty Images) [...] Altitudes,
# landscapes and climates change dramatically as you move across the globe, but one factor remains nearly ubiquitous.
# All of Earth's diversity is blanketed under a blue sky. But why is the sky blue? It's not a reflection of Earth's
# oceans. The real explanation requires a bit of particle physics.", 'score': 0.85097736}, {'title': 'Why Is the Sky
# Blue? | NESDIS', 'url': 'https://www.nesdis.noaa.gov/about/k-12-education/atmosphere/why-the-sky-blue', 'content':
# "> Gases and particles in Earth's atmosphere scatter sunlight in all directions. Blue light is scattered more than
# other colors because it travels as shorter, smaller waves. This is why we see a blue sky most of the time.\n\nNote
# to screen-readers: This page is using an IFrame for the content-area, and you screen reader may not be abel to see
# it on this website. For screen-reading purposes, please go directly to the IFrame's target page by going to . [...]
# Watch this video about why the sky is blue! Voiceover provided by NASA scientist Dr. Moogega Stricker.\n\nLike most
# curious people, you have probably asked at some time, “Why is the sky blue?” Or if you saw a beautiful sunset or
# sunrise, you might have asked, “Why is the sky red?”\n\nIt’s so obvious that the sky is blue, you might think the
# reasons would be just as obvious. They aren’t! Of all the colors of the rainbow, why blue?\n\nCredit:
# NOAA/JPL-Caltech", 'score': 0.8497846}], tool_call_id='call_9myz2dr7', timestamp=datetime.datetime(2025, 11, 4, 19,
# 37, 47, 580608, tzinfo=datetime.timezone.utc))]),
#     ModelResponse(parts=[TextPart(content="## Short Summary of Search Results\n\n| Title | URL | Snippet
# |\n|-------|-----|---------|\n| Why is the sky blue? | <https://www.rmg.co.uk/stories/space-astronomy/why-sky-blue>
# | “Clear skies above the Royal Observatory make for a fantastic view – but why is the sky blue? It’s the Earth’s
# atmosphere, and a process known as ‘scattering’, that causes our skies to be blue… As white light passes through
# our atmosphere, tiny air molecules cause it to ‘scatter’. The scattering caused by these tiny air molecules (known
# as Rayleigh scattering) increases as the wavelength of light decreases.” |\n| Why Is the Sky Blue? |
# <https://spaceplace.nasa.gov/blue-sky/en/> | “Sunlight reaches Earth's atmosphere and is scattered in all
# directions by all the gases and particles in the air. Blue light is scattered more than the other colors because it
# travels as shorter, smaller waves. This is why we see a blue sky most of the time.” |\n| Why Is the Sky Blue? –
# YouTube | <https://www.youtube.com/watch?v=ehUIlhKhzDA> | “…the sky is usually a shade of blue. Why blue—and not
# purple, green, or orange? It’s all because of how the Sun’s light reaches Earth! … The white light from the Sun is
# made of all the colors of the rainbow, and the blue component is scattered in all directions by the tiny molecules
# of air.” |\n| Why is the sky blue? – Live Science | <https://www.livescience.com/planet-earth/why-is-the-sky-blue>
# | “We see blue above us because of how light from the sun interacts with Earth's atmosphere. When the white light
# traveling from the sun reaches Earth, some of the colors interact with molecules and small particles in the
# atmosphere, and blue light is scattered more than other colors.” |\n| Why Is the Sky Blue? |
# <https://www.nesdis.noaa.gov/about/k-12-education/atmosphere/why-the-sky-blue> | “Gases and particles in Earth's
# atmosphere scatter sunlight in all directions. Blue light is scattered more than other colors because it travels as
# shorter, smaller waves.” |\n\nThese sources collectively explain that the sky appears blue due to **Rayleigh
# scattering**: short‑wavelength blue light is scattered more efficiently by the small molecules in Earth's
# atmosphere than longer‑wavelength colors, making the sky’s dominant color blue.")],
# usage=RequestUsage(input_tokens=1930, output_tokens=517), model_name='gpt-oss:20b',
# timestamp=datetime.datetime(2025, 11, 4, 19, 38, 7, tzinfo=TzInfo(0)), provider_name='ollama',
# provider_details={'finish_reason': 'stop'}, provider_response_id='chatcmpl-893', finish_reason='stop')
# ]
